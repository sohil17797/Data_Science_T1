# %%
import pandas as pd

a = pd.read_csv('sample.csv')
print(a)
# Out:
#       Order Date     Customer Name    Segment             City       State  \
# 0      11/8/2016       Claire Gute   Consumer        Henderson    Kentucky
# 1      11/8/2016       Claire Gute   Consumer        Henderson    Kentucky
# 2      6/12/2016   Darrin Van Huff  Corporate      Los Angeles  California
# 3     10/11/2015    Sean O'Donnell   Consumer  Fort Lauderdale     Florida
# 4     10/11/2015    Sean O'Donnell   Consumer  Fort Lauderdale     Florida
# ...          ...               ...        ...              ...         ...
# 9989   1/21/2014  Tom Boeckenhauer   Consumer            Miami     Florida
# 9990   2/26/2017       Dave Brooks   Consumer       Costa Mesa  California
# 9991   2/26/2017       Dave Brooks   Consumer       Costa Mesa  California
# 9992   2/26/2017       Dave Brooks   Consumer       Costa Mesa  California
# 9993    5/4/2017      Chris Cortes   Consumer      Westminster  California
#
# ...

# %%
a.head()
# Out:
#    Order Date    Customer Name    Segment             City       State  \
# 0   11/8/2016      Claire Gute   Consumer        Henderson    Kentucky
# 1   11/8/2016      Claire Gute   Consumer        Henderson    Kentucky
# 2   6/12/2016  Darrin Van Huff  Corporate      Los Angeles  California
# 3  10/11/2015   Sean O'Donnell   Consumer  Fort Lauderdale     Florida
# 4  10/11/2015   Sean O'Donnell   Consumer  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#      Profit
# 0   41.9136
# 1  219.5820
# 2    6.8714
# 3 -383.0310
# 4    2.5164

# %%
a.tail()
# Out:
#      Order Date     Customer Name   Segment         City       State  \
# 9989  1/21/2014  Tom Boeckenhauer  Consumer        Miami     Florida
# 9990  2/26/2017       Dave Brooks  Consumer   Costa Mesa  California
# 9991  2/26/2017       Dave Brooks  Consumer   Costa Mesa  California
# 9992  2/26/2017       Dave Brooks  Consumer   Costa Mesa  California
# 9993   5/4/2017      Chris Cortes  Consumer  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#        Profit
# 9989   4.1028
# 9990  15.6332
# 9991  19.3932
# 9992  13.3200
# 9993  72.9480

# %%
a.head(5)
# Out:
#    Order Date    Customer Name    Segment             City       State  \
# 0   11/8/2016      Claire Gute   Consumer        Henderson    Kentucky
# 1   11/8/2016      Claire Gute   Consumer        Henderson    Kentucky
# 2   6/12/2016  Darrin Van Huff  Corporate      Los Angeles  California
# 3  10/11/2015   Sean O'Donnell   Consumer  Fort Lauderdale     Florida
# 4  10/11/2015   Sean O'Donnell   Consumer  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#      Profit
# 0   41.9136
# 1  219.5820
# 2    6.8714
# 3 -383.0310
# 4    2.5164

# %%
a.columns
# Out:
# Index(['Order Date', 'Customer Name', 'Segment', 'City', 'State',
#        'Postal Code', 'Region', 'Category', 'Sub-Category', 'Sales',
#        'Quantity', 'Profit'],
#       dtype='object')

# %%
a.index
# Out:
# RangeIndex(start=0, stop=9994, step=1)

# %%
a.describe()
# Out:
#         Postal Code         Sales     Quantity       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574    28.656896
# std    32063.693350    623.245101     2.225110   234.260108
# min     1040.000000      0.444000     1.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     8.666500
# 75%    90008.000000    209.940000     5.000000    29.364000
# max    99301.000000  22638.480000    14.000000  8399.976000

# %%
a.columns
# Out:
# Index(['Order Date', 'Customer Name', 'Segment', 'City', 'State',
#        'Postal Code', 'Region', 'Category', 'Sub-Category', 'Sales',
#        'Quantity', 'Profit'],
#       dtype='object')

# %%
a[['Order Date','Customer Name']].head(5)
# Out:
#    Order Date    Customer Name
# 0   11/8/2016      Claire Gute
# 1   11/8/2016      Claire Gute
# 2   6/12/2016  Darrin Van Huff
# 3  10/11/2015   Sean O'Donnell
# 4  10/11/2015   Sean O'Donnell

# %%
a[1:7]
# Out:
#    Order Date    Customer Name    Segment             City       State  \
# 1   11/8/2016      Claire Gute   Consumer        Henderson    Kentucky
# 2   6/12/2016  Darrin Van Huff  Corporate      Los Angeles  California
# 3  10/11/2015   Sean O'Donnell   Consumer  Fort Lauderdale     Florida
# 4  10/11/2015   Sean O'Donnell   Consumer  Fort Lauderdale     Florida
# 5    6/9/2014  Brosina Hoffman   Consumer      Los Angeles  California
# 6    6/9/2014  Brosina Hoffman   Consumer      Los Angeles  California
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
# 5        90032   West        Furniture  Furnishings   48.8600         7
# ...

# %%
a[9990:]
# Out:
#      Order Date Customer Name   Segment         City       State  Postal Code  \
# 9990  2/26/2017   Dave Brooks  Consumer   Costa Mesa  California        92627
# 9991  2/26/2017   Dave Brooks  Consumer   Costa Mesa  California        92627
# 9992  2/26/2017   Dave Brooks  Consumer   Costa Mesa  California        92627
# 9993   5/4/2017  Chris Cortes  Consumer  Westminster  California        92683
#
#      Region         Category Sub-Category    Sales  Quantity   Profit
# 9990   West        Furniture  Furnishings   91.960         2  15.6332
# 9991   West       Technology       Phones  258.576         2  19.3932
# 9992   West  Office Supplies        Paper   29.600         4  13.3200
# 9993   West  Office Supplies   Appliances  243.160         2  72.9480

# %%
a.iloc[1]
# Out:
# Order Date         11/8/2016
# Customer Name    Claire Gute
# Segment             Consumer
# City               Henderson
# State               Kentucky
# Postal Code            42420
# Region                 South
# Category           Furniture
# Sub-Category          Chairs
# Sales                 731.94
# Quantity                   3
# Profit               219.582
# Name: 1, dtype: object

# %%
b = a.to_numpy()

# %%
type(b)
# Out:
# numpy.ndarray

# %%
a.size
# Out:
# 119928

# %%
a.shape
# Out:
# (9994, 12)

# %%
a.memory_usage()
# Out:
# Index              128
# Order Date       79952
# Customer Name    79952
# Segment          79952
# City             79952
# State            79952
# Postal Code      79952
# Region           79952
# Category         79952
# Sub-Category     79952
# Sales            79952
# Quantity         79952
# Profit           79952
# dtype: int64

# %%
a.memory_usage(index=False)
# Out:
# Order Date       79952
# Customer Name    79952
# Segment          79952
# City             79952
# State            79952
# Postal Code      79952
# Region           79952
# Category         79952
# Sub-Category     79952
# Sales            79952
# Quantity         79952
# Profit           79952
# dtype: int64

# %%
import pandas as pd

# %%
jason_pd = pd.read_json('https://jsonplaceholder.typicode.com/users')

# %%
jason_pd
# Out:
#    id                      name          username                      email  \
# 0   1             Leanne Graham              Bret          Sincere@april.biz
# 1   2              Ervin Howell         Antonette          Shanna@melissa.tv
# 2   3          Clementine Bauch          Samantha         Nathan@yesenia.net
# 3   4          Patricia Lebsack          Karianne  Julianne.OConner@kory.org
# 4   5          Chelsey Dietrich            Kamren   Lucio_Hettinger@annie.ca
# 5   6      Mrs. Dennis Schulist  Leopoldo_Corkery    Karley_Dach@jasper.info
# 6   7           Kurtis Weissnat      Elwyn.Skiles     Telly.Hoeger@billy.biz
# 7   8  Nicholas Runolfsdottir V     Maxime_Nienow       Sherwood@rosamond.me
# 8   9           Glenna Reichert          Delphine    Chaim_McDermott@dana.io
# 9  10        Clementina DuBuque    Moriah.Stanton     Rey.Padberg@karina.biz
#
#                                              address                  phone  \
# ...

# %%
df1 = pd.read_csv("demo.csv")
df1
# Out:
#    Order Date    Customer Name    Segment             City       State  \
# 0   11/8/2016      Claire Gute   Consumer        Henderson    Kentucky
# 1   11/8/2016      Claire Gute   Consumer        Henderson    Kentucky
# 2   6/12/2016  Darrin Van Huff  Corporate      Los Angeles  California
# 3  10/11/2015   Sean O'Donnell   Consumer  Fort Lauderdale     Florida
# 4  10/11/2015   Sean O'Donnell   Consumer  Fort Lauderdale     Florida
# 5    6/9/2014  Brosina Hoffman   Consumer              NaN  California
# 6    6/9/2014              NaN   Consumer      Los Angeles  California
# 7         NaN              NaN   Consumer      Los Angeles  California
# 8    6/9/2014  Brosina Hoffman   Consumer      Los Angeles  California
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# ...

# %%
# df1 = pd.read_csv("demo.csv",nrows=1) # it will print given row
# df1 = pd.read_csv("demo.csv",usecols=[1,3]) # it eill print given column
# df1 = pd.read_csv("demo.csv",skiprows=[1,2,3]) # it will skip given rows
# df1 = pd.read_csv("demo.csv",index_col='City') # it will give index to that column
# df1 = pd.read_csv("demo.csv",index_col=3) # it will make index column for given input
# df1 = pd.read_csv("demo.csv",header=1) # it will make give row as an header
# df1 = pd.read_csv("demo.csv",header=None,prefix="col") # it will give header as given string
# df1 = pd.read_csv("demo.csv",names=['Date', 'Name', 'Segment', 'City', 'State','PinCode', 'Region', 'Category', 'Sub-Category', 'Sales','Quantity', 'Profit'])
# df1 = pd.read_csv("demo.csv",dtype={"Quantity":float})
# df1 = pd.read_csv("demo.csv",na_values=['Florida']) # it will write NaN for given string

df1
# Out:
#    Order Date    Customer Name    Segment             City       State  \
# 0   11/8/2016      Claire Gute   Consumer        Henderson    Kentucky
# 1   11/8/2016      Claire Gute   Consumer        Henderson    Kentucky
# 2   6/12/2016  Darrin Van Huff  Corporate      Los Angeles  California
# 3  10/11/2015   Sean O'Donnell   Consumer  Fort Lauderdale     Florida
# 4  10/11/2015   Sean O'Donnell   Consumer  Fort Lauderdale     Florida
# 5    6/9/2014  Brosina Hoffman   Consumer      Los Angeles  California
# 6    6/9/2014  Brosina Hoffman   Consumer      Los Angeles  California
# 7    6/9/2014  Brosina Hoffman   Consumer      Los Angeles  California
# 8    6/9/2014  Brosina Hoffman   Consumer      Los Angeles  California
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600       2.0
# 1        42420  South        Furniture       Chairs  731.9400       3.0
# ...

# %% [markdown]
# # 21/12/2022

# %%
import pandas as pd
df1 = pd.read_csv("demo.csv")

# %%
df1
# Out:
#    Order Date    Customer Name    Segment             City       State  \
# 0   11/8/2016      Claire Gute   Consumer        Henderson    Kentucky
# 1   11/8/2016      Claire Gute   Consumer        Henderson    Kentucky
# 2   6/12/2016  Darrin Van Huff  Corporate      Los Angeles  California
# 3  10/11/2015   Sean O'Donnell   Consumer  Fort Lauderdale     Florida
# 4  10/11/2015   Sean O'Donnell   Consumer  Fort Lauderdale     Florida
# 5    6/9/2014  Brosina Hoffman   Consumer              NaN  California
# 6    6/9/2014              NaN   Consumer      Los Angeles  California
# 7         NaN              NaN   Consumer      Los Angeles  California
# 8    6/9/2014  Brosina Hoffman   Consumer      Los Angeles  California
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# ...

# %%
df1.fillna('hello')
# Out:
#    Order Date    Customer Name    Segment             City       State  \
# 0   11/8/2016      Claire Gute   Consumer        Henderson    Kentucky
# 1   11/8/2016      Claire Gute   Consumer        Henderson    Kentucky
# 2   6/12/2016  Darrin Van Huff  Corporate      Los Angeles  California
# 3  10/11/2015   Sean O'Donnell   Consumer  Fort Lauderdale     Florida
# 4  10/11/2015   Sean O'Donnell   Consumer  Fort Lauderdale     Florida
# 5    6/9/2014  Brosina Hoffman   Consumer      Los Angeles  California
# 6    6/9/2014            hello   Consumer      Los Angeles  California
# 7    6/9/2014            hello   Consumer      Los Angeles  California
# 8    6/9/2014  Brosina Hoffman   Consumer      Los Angeles  California
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# ...

# %%
df1.fillna({'Customer Name':'unknown'})
df1
# Out:
#    Order Date    Customer Name    Segment             City       State  \
# 0   11/8/2016      Claire Gute   Consumer        Henderson    Kentucky
# 1   11/8/2016      Claire Gute   Consumer        Henderson    Kentucky
# 2   6/12/2016  Darrin Van Huff  Corporate      Los Angeles  California
# 3  10/11/2015   Sean O'Donnell   Consumer  Fort Lauderdale     Florida
# 4  10/11/2015   Sean O'Donnell   Consumer  Fort Lauderdale     Florida
# 5    6/9/2014  Brosina Hoffman   Consumer              NaN  California
# 6    6/9/2014              NaN   Consumer      Los Angeles  California
# 7         NaN              NaN   Consumer      Los Angeles  California
# 8    6/9/2014  Brosina Hoffman   Consumer      Los Angeles  California
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# ...

# %%
df1.fillna(method='bfill')
df1
# Out:
#    Order Date    Customer Name    Segment             City       State  \
# 0   11/8/2016      Claire Gute   Consumer        Henderson    Kentucky
# 1   11/8/2016      Claire Gute   Consumer        Henderson    Kentucky
# 2   6/12/2016  Darrin Van Huff  Corporate      Los Angeles  California
# 3  10/11/2015   Sean O'Donnell   Consumer  Fort Lauderdale     Florida
# 4  10/11/2015   Sean O'Donnell   Consumer  Fort Lauderdale     Florida
# 5    6/9/2014  Brosina Hoffman   Consumer              NaN  California
# 6    6/9/2014              NaN   Consumer      Los Angeles  California
# 7         NaN              NaN   Consumer      Los Angeles  California
# 8    6/9/2014  Brosina Hoffman   Consumer      Los Angeles  California
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# ...

# %%
df2 = pd.read_csv('sample1.csv')

# %%
# df2.fillna({'Customer Name':'None','Sub-Category':'nothing','Quantity':'0'})
# df2.fillna(0)
# df2.fillna(method="ffill")
# df2.fillna(method="bfill")
# df2.fillna(method="pad")
# df2.fillna(method="ffill ")

# df2.fillna(method='bfill',axis=0) #Must specify a fill 'value' or 'method'.
# df2.fillna(0,limit=2)
# df2.fillna(method="bfill",limit=1)
df2.fillna(3,inplace=True)
df2
# Out:
#     Order Date    Customer Name      Segment             City           State  \
# 0    11/8/2016      Claire Gute     Consumer        Henderson        Kentucky
# 1    11/8/2016      Claire Gute     Consumer        Henderson        Kentucky
# 2    6/12/2016  Darrin Van Huff    Corporate      Los Angeles      California
# 3   10/11/2015   Sean O'Donnell     Consumer  Fort Lauderdale         Florida
# 4   10/11/2015   Sean O'Donnell     Consumer  Fort Lauderdale         Florida
# 5     6/9/2014   Sean O'Donnell     Consumer      Los Angeles         Florida
# 6     6/9/2014   Sean O'Donnell     Consumer      Los Angeles         Florida
# 7     6/9/2014   Sean O'Donnell     Consumer      Los Angeles         Florida
# 8     6/9/2014   Sean O'Donnell     Consumer      Los Angeles         Florida
# 9     6/9/2014   Sean O'Donnell     Consumer      Los Angeles         Florida
# 10    6/9/2014  Brosina Hoffman     Consumer      Los Angeles      California
# ...

# %%
df2.replace("Phones","iphone")
# Out:
#     Order Date    Customer Name      Segment             City           State  \
# 0    11/8/2016      Claire Gute     Consumer        Henderson        Kentucky
# 1    11/8/2016      Claire Gute     Consumer        Henderson        Kentucky
# 2    6/12/2016  Darrin Van Huff    Corporate      Los Angeles      California
# 3   10/11/2015   Sean O'Donnell     Consumer  Fort Lauderdale         Florida
# 4   10/11/2015   Sean O'Donnell     Consumer  Fort Lauderdale         Florida
# 5     6/9/2014              NaN     Consumer      Los Angeles             NaN
# 6     6/9/2014              NaN     Consumer      Los Angeles             NaN
# 7     6/9/2014              NaN     Consumer      Los Angeles             NaN
# 8     6/9/2014              NaN     Consumer      Los Angeles             NaN
# 9     6/9/2014              NaN     Consumer      Los Angeles             NaN
# 10    6/9/2014  Brosina Hoffman     Consumer      Los Angeles      California
# ...

# %% [markdown]
# # 22/12/2022

# %%
df2.interpolate(method="linear")
# Out:
#     Order Date    Customer Name      Segment             City           State  \
# 0    11/8/2016      Claire Gute     Consumer        Henderson        Kentucky
# 1    11/8/2016      Claire Gute     Consumer        Henderson        Kentucky
# 2    6/12/2016  Darrin Van Huff    Corporate      Los Angeles      California
# 3   10/11/2015   Sean O'Donnell     Consumer  Fort Lauderdale         Florida
# 4   10/11/2015   Sean O'Donnell     Consumer  Fort Lauderdale         Florida
# 5     6/9/2014              NaN     Consumer      Los Angeles             NaN
# 6     6/9/2014              NaN     Consumer      Los Angeles             NaN
# 7     6/9/2014              NaN     Consumer      Los Angeles             NaN
# 8     6/9/2014              NaN     Consumer      Los Angeles             NaN
# 9     6/9/2014              NaN     Consumer      Los Angeles             NaN
# 10    6/9/2014  Brosina Hoffman     Consumer      Los Angeles      California
# ...

# %%
df2.interpolate(method="polynomial",order=1)
# Out:
#     Order Date    Customer Name      Segment             City           State  \
# 0    11/8/2016      Claire Gute     Consumer        Henderson        Kentucky
# 1    11/8/2016      Claire Gute     Consumer        Henderson        Kentucky
# 2    6/12/2016  Darrin Van Huff    Corporate      Los Angeles      California
# 3   10/11/2015   Sean O'Donnell     Consumer  Fort Lauderdale         Florida
# 4   10/11/2015   Sean O'Donnell     Consumer  Fort Lauderdale         Florida
# 5     6/9/2014              NaN     Consumer      Los Angeles             NaN
# 6     6/9/2014              NaN     Consumer      Los Angeles             NaN
# 7     6/9/2014              NaN     Consumer      Los Angeles             NaN
# 8     6/9/2014              NaN     Consumer      Los Angeles             NaN
# 9     6/9/2014              NaN     Consumer      Los Angeles             NaN
# 10    6/9/2014  Brosina Hoffman     Consumer      Los Angeles      California
# ...

# %%
df2 = pd.read_csv("sample1.csv",parse_dates=["Order Date"])

# %%
df2
# Out:
#    Order Date    Customer Name      Segment             City           State  \
# 0  2016-11-08      Claire Gute     Consumer        Henderson        Kentucky
# 1  2016-11-08      Claire Gute     Consumer        Henderson        Kentucky
# 2  2016-06-12  Darrin Van Huff    Corporate      Los Angeles      California
# 3  2015-10-11   Sean O'Donnell     Consumer  Fort Lauderdale         Florida
# 4  2015-10-11   Sean O'Donnell     Consumer  Fort Lauderdale         Florida
# 5  2014-06-09              NaN     Consumer      Los Angeles             NaN
# 6  2014-06-09              NaN     Consumer      Los Angeles             NaN
# 7  2014-06-09              NaN     Consumer      Los Angeles             NaN
# 8  2014-06-09              NaN     Consumer      Los Angeles             NaN
# 9  2014-06-09              NaN     Consumer      Los Angeles             NaN
# 10 2014-06-09  Brosina Hoffman     Consumer      Los Angeles      California
# ...

# %%
df2 = pd.read_csv("sample1.csv",parse_dates=["Order Date"],index_col="Order Date")
df2
# Out:
#               Customer Name      Segment             City           State  \
# Order Date
# 2016-11-08      Claire Gute     Consumer        Henderson        Kentucky
# 2016-11-08      Claire Gute     Consumer        Henderson        Kentucky
# 2016-06-12  Darrin Van Huff    Corporate      Los Angeles      California
# 2015-10-11   Sean O'Donnell     Consumer  Fort Lauderdale         Florida
# 2015-10-11   Sean O'Donnell     Consumer  Fort Lauderdale         Florida
# 2014-06-09              NaN     Consumer      Los Angeles             NaN
# 2014-06-09              NaN     Consumer      Los Angeles             NaN
# 2014-06-09              NaN     Consumer      Los Angeles             NaN
# 2014-06-09              NaN     Consumer      Los Angeles             NaN
# 2014-06-09              NaN     Consumer      Los Angeles             NaN
# 2014-06-09  Brosina Hoffman     Consumer      Los Angeles      California
# ...

# %%
df2.interpolate(method="time")
# Out:
#               Customer Name      Segment             City           State  \
# Order Date
# 2016-11-08      Claire Gute     Consumer        Henderson        Kentucky
# 2016-11-08      Claire Gute     Consumer        Henderson        Kentucky
# 2016-06-12  Darrin Van Huff    Corporate      Los Angeles      California
# 2015-10-11   Sean O'Donnell     Consumer  Fort Lauderdale         Florida
# 2015-10-11   Sean O'Donnell     Consumer  Fort Lauderdale         Florida
# 2014-06-09              NaN     Consumer      Los Angeles             NaN
# 2014-06-09              NaN     Consumer      Los Angeles             NaN
# 2014-06-09              NaN     Consumer      Los Angeles             NaN
# 2014-06-09              NaN     Consumer      Los Angeles             NaN
# 2014-06-09              NaN     Consumer      Los Angeles             NaN
# 2014-06-09  Brosina Hoffman     Consumer      Los Angeles      California
# ...

# %%
df2 = pd.read_csv("sample1.csv",parse_dates=["Order Date"],index_col="Order Date")
df2.interpolate(method="linear")
# Out:
#               Customer Name      Segment             City           State  \
# Order Date
# 2016-11-08      Claire Gute     Consumer        Henderson        Kentucky
# 2016-11-08      Claire Gute     Consumer        Henderson        Kentucky
# 2016-06-12  Darrin Van Huff    Corporate      Los Angeles      California
# 2015-10-11   Sean O'Donnell     Consumer  Fort Lauderdale         Florida
# 2015-10-11   Sean O'Donnell     Consumer  Fort Lauderdale         Florida
# 2014-06-09              NaN     Consumer      Los Angeles             NaN
# 2014-06-09              NaN     Consumer      Los Angeles             NaN
# 2014-06-09              NaN     Consumer      Los Angeles             NaN
# 2014-06-09              NaN     Consumer      Los Angeles             NaN
# 2014-06-09              NaN     Consumer      Los Angeles             NaN
# 2014-06-09  Brosina Hoffman     Consumer      Los Angeles      California
# ...

# %% [markdown]
# # 23/12/2022
